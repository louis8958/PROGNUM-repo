# %% [markdown]
# # Energy and frequency
#
# With Planck's constant $h$, we write the relation between energy and frequency as:
#
# $$E = hf$$

# %% [markdown]
# Question 2.1
#
# $$E = hc / \lambda $$
#
# $$ E = \frac{hc}{\lambda} $$

# %% [markdown]
# Question 2.2
#
# $$ F = G \frac{m_1 m_2}{r^2} $$

# %% [markdown]
# Question 2.3
#
# $$ \sin(2x) = 2\sin(x)\cos(x) = \frac{2\tan(x)}{1 + \tan(x)^2} $$

# %%
#Question 2.4
#
from math import *
alpha_D = 30
alpha_R = radians(alpha_D)

A = sin(2*alpha_R)
print (f'A equals {A:g}')

B = 2*sin(alpha_R)*cos(alpha_R)
print (f'B equals {B:g}')

C = (2*tan(alpha_R))/(1+ (tan(alpha_R)**2))
print (f'C equals {C:g}')
# Out:
# A equals 0.866025
# B equals 0.866025
# C equals 0.866025

# %% [markdown]
# Question 2.5
#
# $$ \displaystyle\sum_{k=0}^{\infty} \frac{1}{4k^2 -1} = \frac{1}{2} $$
#
# $$ \int_0^\pi \mathrm{e}^{ix}\, \mathrm{d}x = 2i $$

# %%
from IPython.display import display, Math
from math import sin, pi

x = 9
Lambda = 0.5

s = rf"\sqrt({x}) = {x**0.5}\ and \sin(\lambda \pi)={sin(Lambda*pi)}"
print(s)
m = Math(s)
display(m)
# Out:
# \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0
# $\displaystyle \sqrt(9) = 3.0\ and \sin(\lambda \pi)=1.0$

# %%
#Question 2.8
#
from math import exp, log

s = rf"\exp(log(x)) = x"
m = Math(s)
display(m)
# Out:
# $\displaystyle \exp(log(x)) = x$

# %%
#Question 2.9
#
from math import factorial

a = factorial(100)
print(a)
# Out:
# 93326215443944152681699238856266700490715968264381621468592963895217599993229915608941463976156518286253697920827223758251185210916864000000000000000000000000

# %% [markdown]
# They are no limits for the number of integer number

# %%
#Question 2.11
#
from math import *
x = 2
y = 3
a = atan2(y, x)
print (a)
if tan(a) == x/y :
    print ('yeeey')
else :
    print ('noooo')
# Out:
# 0.982793723247329
# noooo

# %%
#Question 2.12
from math import atan2, degrees

#Inputs for x and y
x = float(input('x equals in degrees'))
y = float(input('y equals in degrees'))

#Calculates the angle between the origin and (x,y)
a = atan2(y, x)
print(a)

#Determines the section of the quadrant 
if x > 0 and y > 0 : 
    print ('The Quadrant is I')
elif x > 0 and y < 0 :
    print ('The Quadrant is IV')
elif x < 0 and y > 0 :
    print ('The Quadrant is II')
else : 
    print ('The Quadrant is III')
# Out:
# x equals in degrees-1
# y equals in degrees2
# 2.0344439357957027
# The Quadrant is II

# %%
#Question 2.14

X = [1.36,  1.46,  1.41,  2.12,  0.42,  0.98,  0.45,  1.97, -0.24, 2.18]
X.append (0.51)
X.remove(2.12)
print (X)
X_6 = X[6]
print (X_6)
X.index (1.46)

slice_X = X[2:8:2]
print (slice_X)
print (sum(slice_X))
# Out:
# [1.36, 1.46, 1.41, 0.42, 0.98, 0.45, 1.97, -0.24, 2.18, 0.51]
# 1.97
# [1.41, 0.98, 1.97]
# 4.359999999999999

# %%
#Question 2.15

night1 = [1,3,2,4,0,3,7,5,2,9,2,4,3]
night2 = [0,0,2,4,2,4,3,2,1,1,1,2,0]

A = set(night1)
B = set(night2)

inter = set.intersection(A, B)
int_list = list(inter)
print(int_list)

if 5 in int_list :
    print ('5 is in the intersection list')
else : 
    print ('5is not in the intersection list')
    
if 5 in A :
    print ('5 is in the night1 set')
else : 
    print ('5is not in the night1 set')
# Out:
# [0, 1, 2, 3, 4]
# 5is not in the intersection list
# 5 is in the night1 set

# %%
#Question 2.19
import numpy as np
mean = 0.0
st_dev = 1.4
nb = 100000

A = np.random.normal(mean, st_dev, nb)
calculated_std = np.std(A)

print (f'The standard deviation is  {calculated_std}')
# Out:
# The standard deviation is  1.4002576672297649

# %%
#Question 2.21

a = 1
b = 2
lllist = [1, 2]

for _ in range (98) :
    c = a + b
    lllist.append(c)
    a = b
    b = c
    

print (b)
print(lllist)
# Out:
# 573147844013817084101
# ...
